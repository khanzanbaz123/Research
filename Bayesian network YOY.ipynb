# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('nayasa.xlsx', parse_dates=['Date'], index_col='Date')
df.head()
# Out:
#             Weighted average call rate   Bank credit  policy rate  real ER  \
# Date
# 2014-01-01                         NaN  5.845459e+06          NaN    85.08
# 2014-02-01                         NaN  5.933025e+06          NaN    84.60
# 2014-03-01                         NaN  5.994096e+06          NaN    86.50
# 2014-04-01                         NaN  6.013472e+06          NaN    87.80
# 2014-05-01                         NaN  6.041520e+06          NaN    89.63
#
#              asset price         GPR  CPI           gdp    investment  \
# Date
# 2014-01-01  20943.422609   77.915970  NaN  2.358104e+06  2.229723e+06
# 2014-02-01  20521.340526   69.003525  NaN  2.367629e+06  2.237513e+06
# 2014-03-01  21815.714762  119.838554  NaN  2.377154e+06  2.212821e+06
# 2014-04-01  22569.499444   93.221542  NaN  2.377888e+06  2.265301e+06
# 2014-05-01  23745.902857   83.428856  NaN  2.378622e+06  2.292490e+06
#
#             net export
# Date
# 2014-01-01 -58691.2899
# 2014-02-01 -51726.1980
# ...

# %%
df1 = pd.read_excel('nayasa.xlsx',  parse_dates=['Date'], index_col='Date')
df1.head()
# Out:
#             Weighted average call rate   Bank credit  policy rate  real ER  \
# Date
# 2014-01-01                         NaN  5.845459e+06          NaN    85.08
# 2014-02-01                         NaN  5.933025e+06          NaN    84.60
# 2014-03-01                         NaN  5.994096e+06          NaN    86.50
# 2014-04-01                         NaN  6.013472e+06          NaN    87.80
# 2014-05-01                         NaN  6.041520e+06          NaN    89.63
#
#              asset price         GPR  CPI           gdp    investment  \
# Date
# 2014-01-01  20943.422609   77.915970  NaN  2.358104e+06  2.229723e+06
# 2014-02-01  20521.340526   69.003525  NaN  2.367629e+06  2.237513e+06
# 2014-03-01  21815.714762  119.838554  NaN  2.377154e+06  2.212821e+06
# 2014-04-01  22569.499444   93.221542  NaN  2.377888e+06  2.265301e+06
# 2014-05-01  23745.902857   83.428856  NaN  2.378622e+06  2.292490e+06
#
#             net export
# Date
# 2014-01-01 -58691.2899
# 2014-02-01 -51726.1980
# ...

# %%
df['creditgrowth'] = df['Bank credit'].pct_change(periods=12)*100
df['assetgrowth'] = df['asset price'].pct_change(periods=12)*100
df['gdpRate'] = df['gdp'].pct_change(periods=12)*100
df['investmentRate'] = df['investment'].pct_change(periods=12)*100
df['netexportRate'] = df['net export'].pct_change(periods=12)*100
df['realErRate'] = df['real ER'].pct_change(periods=12)*100
df['GPrRate'] = df['GPR'].pct_change(periods=12)*100

# %%
df
# Out:
#             Weighted average call rate   Bank credit  policy rate  real ER  \
# Date
# 2014-01-01                         NaN  5.845459e+06          NaN    85.08
# 2014-02-01                         NaN  5.933025e+06          NaN    84.60
# 2014-03-01                         NaN  5.994096e+06          NaN    86.50
# 2014-04-01                         NaN  6.013472e+06          NaN    87.80
# 2014-05-01                         NaN  6.041520e+06          NaN    89.63
# ...                                ...           ...          ...      ...
# 2022-05-01                        4.09  1.206273e+07          4.0   101.92
# 2022-06-01                        4.61  1.219043e+07          4.4   100.98
# 2022-07-01                        5.04  1.236935e+07          4.9   100.88
# 2022-08-01                        5.10  1.245866e+07          4.9   101.44
# 2022-09-01                        5.52  1.304179e+07          5.4   103.03
#
# ...

# %%
df.index[0:12]
# Out:
# DatetimeIndex(['2014-01-01', '2014-02-01', '2014-03-01', '2014-04-01',
#                '2014-05-01', '2014-06-01', '2014-07-01', '2014-08-01',
#                '2014-09-01', '2014-10-01', '2014-11-01', '2014-12-01'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
df = df.drop(df.index[0:12])

# %%
df
# Out:
#             Weighted average call rate   Bank credit  policy rate  real ER  \
# Date
# 2015-01-01                        7.89  6.386975e+06         7.75    95.19
# 2015-02-01                        7.69  6.459716e+06         7.75    95.83
# 2015-03-01                        7.58  6.536420e+06         7.50    96.65
# 2015-04-01                        7.44  6.573263e+06         7.50    95.98
# 2015-05-01                        7.47  6.606344e+06         7.50    94.11
# ...                                ...           ...          ...      ...
# 2022-05-01                        4.09  1.206273e+07         4.00   101.92
# 2022-06-01                        4.61  1.219043e+07         4.40   100.98
# 2022-07-01                        5.04  1.236935e+07         4.90   100.88
# 2022-08-01                        5.10  1.245866e+07         4.90   101.44
# 2022-09-01                        5.52  1.304179e+07         5.40   103.03
#
# ...

# %%
df1['creditgrowth'] = df1['Bank credit'].pct_change(periods=12)*100
df1['assetgrowth'] = df1['asset price'].pct_change(periods=12)*100
df1['gdpRate'] = df1['gdp'].pct_change(periods=12)*100
df1['investmentRate'] = df1['investment'].pct_change(periods=12)*100
df1['netexportRate'] = df1['net export'].pct_change(periods=12)*100
df1['netexportRate'] = df1['net export'].pct_change(periods=12)*100
df1['real ER growth'] = df1['real ER'].pct_change(periods=12)*100
df1['GPrRate'] = df1['GPR'].pct_change(periods=12)*100

# %%
df1 = df1.drop(df1.index[0:12])

# %%
df1
# Out:
#             Weighted average call rate   Bank credit  policy rate  real ER  \
# Date
# 2015-01-01                        7.89  6.386975e+06         7.75    95.19
# 2015-02-01                        7.69  6.459716e+06         7.75    95.83
# 2015-03-01                        7.58  6.536420e+06         7.50    96.65
# 2015-04-01                        7.44  6.573263e+06         7.50    95.98
# 2015-05-01                        7.47  6.606344e+06         7.50    94.11
# ...                                ...           ...          ...      ...
# 2022-05-01                        4.09  1.206273e+07         4.00   101.92
# 2022-06-01                        4.61  1.219043e+07         4.40   100.98
# 2022-07-01                        5.04  1.236935e+07         4.90   100.88
# 2022-08-01                        5.10  1.245866e+07         4.90   101.44
# 2022-09-01                        5.52  1.304179e+07         5.40   103.03
#
# ...

# %%
df.columns
# Out:
# Index(['Weighted average call rate', 'Bank credit', 'policy rate', 'real ER',
#        'asset price', 'GPR', 'CPI', 'gdp', 'investment', 'net export',
#        'creditgrowth', 'assetgrowth', 'gdpRate', 'investmentRate',
#        'netexportRate', 'realErRate', 'GPrRate'],
#       dtype='object')

# %%
df.drop([ 'Bank credit' , 'asset price', 'gdp', 'investment', 'net export', 'real ER' ,'GPR'], axis = 1, inplace = True)

# %%
df
# Out:
#             Weighted average call rate  policy rate   CPI  creditgrowth  \
# Date
# 2015-01-01                        7.89         7.75  5.19      9.263881
# 2015-02-01                        7.69         7.75  5.37      8.877285
# 2015-03-01                        7.58         7.50  5.25      9.047648
# 2015-04-01                        7.44         7.50  4.87      9.308951
# 2015-05-01                        7.47         7.50  5.01      9.349022
# ...                                ...          ...   ...           ...
# 2022-05-01                        4.09         4.00  7.00     11.434577
# 2022-06-01                        4.61         4.40  7.00     12.252593
# 2022-07-01                        5.04         4.90  6.70     13.370371
# 2022-08-01                        5.10         4.90  7.00     14.324775
# 2022-09-01                        5.52         5.40  7.41     19.029013
#
#             assetgrowth   gdpRate  investmentRate  netexportRate  realErRate  \
# Date
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 93 entries, 2015-01-01 to 2022-09-01
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Weighted average call rate  93 non-null     float64
#  1   Bank credit                 93 non-null     float64
#  2   policy rate                 93 non-null     float64
#  3   real ER                     93 non-null     float64
#  4   asset price                 93 non-null     float64
#  5   GPR                         93 non-null     float64
#  6   CPI                         93 non-null     float64
#  7   gdp                         93 non-null     float64
#  8   investment                  93 non-null     float64
#  9   net export                  93 non-null     float64
#  10  creditgrowth                93 non-null     float64
#  11  assetgrowth                 93 non-null     float64
# ...

# %%
df1.describe()
# Out:
#        Weighted average call rate   Bank credit  policy rate     real ER  \
# count                   93.000000  9.300000e+01    93.000000   93.000000
# mean                     5.380538  9.091705e+06     5.606989   99.132473
# std                      1.404859  1.765514e+06     1.174586    2.377497
# min                      3.120000  6.386975e+06     4.000000   93.500000
# 25%                      3.720000  7.410062e+06     4.000000   97.390000
# 50%                      5.910000  9.221898e+06     6.000000   99.420000
# 75%                      6.390000  1.038795e+07     6.500000  101.010000
# max                      7.890000  1.304179e+07     7.750000  103.370000
#
#         asset price         GPR        CPI           gdp    investment  \
# count     93.000000   93.000000  93.000000  9.300000e+01  9.300000e+01
# mean   37748.222117  102.129143   4.876882  3.118849e+06  3.620493e+06
# std    10689.875474   35.317894   1.497780  3.277301e+05  7.479108e+05
# ...

# %%
df1.corr()
# Out:
#                             Weighted average call rate  Bank credit  \
# Weighted average call rate                    1.000000    -0.826997
# Bank credit                                  -0.826997     1.000000
# policy rate                                   0.986443    -0.875367
# real ER                                      -0.491170     0.443662
# asset price                                  -0.774114     0.911522
# GPR                                           0.003768     0.144360
# CPI                                          -0.454262     0.427654
# gdp                                          -0.725630     0.879111
# investment                                   -0.895643     0.955769
# net export                                    0.245195    -0.602819
# creditgrowth                                  0.441499     0.046647
# assetgrowth                                  -0.316928     0.217777
# gdpRate                                       0.116411    -0.182221
# ...

# %%
df.corr()
# Out:
#                             Weighted average call rate  policy rate       CPI  \
# Weighted average call rate                    1.000000     0.986443 -0.454262
# policy rate                                   0.986443     1.000000 -0.488499
# CPI                                          -0.454262    -0.488499  1.000000
# creditgrowth                                  0.441499     0.377675 -0.169284
# assetgrowth                                  -0.316928    -0.240880 -0.076279
# gdpRate                                       0.116411     0.193550 -0.180192
# investmentRate                               -0.156308    -0.112315  0.095236
# netexportRate                                 0.036636     0.018753 -0.135664
# realErRate                                    0.288816     0.298083  0.115625
# GPrRate                                      -0.199017    -0.219224  0.301089
#
#                             creditgrowth  assetgrowth   gdpRate  \
# ...

# %%
df[['policy rate', 'CPI']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import seaborn as sns

# %%
sns.distplot(df["Weighted average call rate"])
# Out:
# C:\Users\NIYAZ AHMED\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weighted average call rate', ylabel='Density'>

# %%
sns.histplot(data=df, x="Weighted average call rate" ,stat = 'frequency')
# Out:
# <AxesSubplot:xlabel='Weighted average call rate', ylabel='Frequency'>

# %%
df.columns
# Out:
# Index(['Weighted average call rate', 'policy rate', 'CPI', 'creditgrowth',
#        'assetgrowth', 'gdpRate', 'investmentRate', 'netexportRate',
#        'realErRate', 'GPrRate'],
#       dtype='object')

# %%
sns.distplot(df['policy rate'])
# Out:
# C:\Users\NIYAZ AHMED\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='policy rate', ylabel='Density'>

# %%
sns.histplot(data=df, x='policy rate' ,stat = 'frequency')
# Out:
# <AxesSubplot:xlabel='policy rate', ylabel='Frequency'>

# %%
sns.distplot(df['CPI'])
# Out:
# C:\Users\NIYAZ AHMED\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CPI', ylabel='Density'>

# %%
sns.histplot(data=df, x='CPI' ,stat = 'frequency')
# Out:
# <AxesSubplot:xlabel='CPI', ylabel='Frequency'>

# %%
df.columns
# Out:
# Index(['Weighted average call rate', 'policy rate', 'CPI', 'creditgrowth',
#        'assetgrowth', 'gdpRate', 'investmentRate', 'netexportRate',
#        'realErRate', 'GPrRate'],
#       dtype='object')

# %%
sns.distplot(df['creditgrowth'])
# Out:
# C:\Users\NIYAZ AHMED\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='creditgrowth', ylabel='Density'>

# %%
sns.histplot(data=df, x='creditgrowth' ,stat = 'frequency')
# Out:
# <AxesSubplot:xlabel='creditgrowth', ylabel='Frequency'>

# %%
sns.distplot(df['assetgrowth'])
# Out:
# C:\Users\NIYAZ AHMED\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='assetgrowth', ylabel='Density'>

# %%
sns.histplot(data=df, x='assetgrowth' ,stat = 'frequency')
# Out:
# <AxesSubplot:xlabel='assetgrowth', ylabel='Frequency'>

# %%
df.columns
# Out:
# Index(['Weighted average call rate', 'policy rate', 'CPI', 'creditgrowth',
#        'assetgrowth', 'gdpRate', 'investmentRate', 'netexportRate',
#        'realErRate', 'GPrRate'],
#       dtype='object')

# %%
sns.distplot(df['gdpRate'])
# Out:
# C:\Users\NIYAZ AHMED\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='gdpRate', ylabel='Density'>

# %%
sns.histplot(data=df, x='gdpRate',stat = 'frequency')
# Out:
# <AxesSubplot:xlabel='gdpRate', ylabel='Frequency'>

# %%
sns.distplot(df['investmentRate'])
# Out:
# C:\Users\NIYAZ AHMED\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='investmentRate', ylabel='Density'>

# %%
sns.histplot(data=df, x='investmentRate' ,stat = 'frequency')
# Out:
# <AxesSubplot:xlabel='investmentRate', ylabel='Frequency'>

# %%
df.columns
# Out:
# Index(['Weighted average call rate', 'policy rate', 'CPI', 'creditgrowth',
#        'assetgrowth', 'gdpRate', 'investmentRate', 'netexportRate',
#        'realErRate', 'GPrRate'],
#       dtype='object')

# %%
sns.distplot(df['netexportRate'])
# Out:
# C:\Users\NIYAZ AHMED\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='netexportRate', ylabel='Density'>

# %%
sns.histplot(data=df, x='netexportRate' ,stat = 'frequency')
# Out:
# <AxesSubplot:xlabel='netexportRate', ylabel='Frequency'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 93 entries, 2015-01-01 to 2022-09-01
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Weighted average call rate  93 non-null     float64
#  1   policy rate                 93 non-null     float64
#  2   CPI                         93 non-null     float64
#  3   creditgrowth                93 non-null     float64
#  4   assetgrowth                 93 non-null     float64
#  5   gdpRate                     93 non-null     float64
#  6   investmentRate              93 non-null     float64
#  7   netexportRate               93 non-null     float64
#  8   realErRate                  93 non-null     float64
#  9   GPrRate                     93 non-null     float64
# dtypes: float64(10)
# memory usage: 8.0 KB

# %%
# Plot
fig, axes = plt.subplots(nrows=5, ncols=2, dpi=300, figsize=(10,10))
for i, ax in enumerate(axes.flatten()):
 data = df[df.columns[i]]
 ax.plot(data, color='red', linewidth=1)
 # Decorations
 ax.set_title(df.columns[i])
 ax.xaxis.set_ticks_position('none')
 ax.yaxis.set_ticks_position('none')
 ax.spines["top"].set_alpha(0)
 ax.tick_params(labelsize=6)
plt.tight_layout();

# %%
# Plot
fig, axes = plt.subplots(nrows=4, ncols=4, dpi=300, figsize=(10,10))
for i, ax in enumerate(axes.flatten()):
 data = df1[df1.columns[i]]
 ax.plot(data, color='blue', linewidth=1)
 # Decorations
 ax.set_title(df1.columns[i])
 ax.xaxis.set_ticks_position('none')
 ax.yaxis.set_ticks_position('none')
 ax.spines["top"].set_alpha(0)
 ax.tick_params(labelsize=6)
plt.tight_layout();

# %%
df.describe()
# Out:
#        Weighted average call rate  policy rate        CPI  creditgrowth  \
# count                   93.000000    93.000000  93.000000     93.000000
# mean                     5.380538     5.606989   4.876882      9.077119
# std                      1.404859     1.174586   1.497780      3.051296
# min                      3.120000     4.000000   1.460000      3.646048
# 25%                      3.720000     4.000000   3.690000      6.518715
# 50%                      5.910000     6.000000   4.920000      8.815138
# 75%                      6.390000     6.500000   5.840000     10.911086
# max                      7.890000     7.750000   7.790000     19.029013
#
#        assetgrowth    gdpRate  investmentRate  netexportRate  realErRate  \
# count    93.000000  93.000000       93.000000      93.000000   93.000000
# mean     12.828732   5.509113       10.051608      12.261718    1.660947
# std      17.070718   5.594584        7.121587     173.654066    4.097177
# ...

# %% [markdown]
# # Assigning Probability

# %%
df.columns
# Out:
# Index(['Weighted average call rate', 'policy rate', 'CPI', 'creditgrowth',
#        'assetgrowth', 'gdpRate', 'investmentRate', 'netexportRate',
#        'realErRate', 'GPrRate'],
#       dtype='object')

# %%
df['pr']=df['policy rate'].apply(lambda x: '<=4' if x<=4 else '4.0 to 4.5' if 4<x<=4.5 else '4.5 to 5.0' if 4.5<x<=5.0
                                 else '5.0 to 5.5' if 5.0<x<=5.5 else '5.5 to 6.0' if 5.5<x<=6.0
                                 else '6 to 6.5' if 6.0<x<=6.5 else '6.5 to 7.0' if 6.5<x<=7.0
                                 else '7.0 to 7.5' if 7.0<x<=7.5else '7.5 to 8.0' if 7.5<x<=8.0 else '>8.0')

# %% [raw]
# df['pr']=df['policy rate'].apply(lambda x: '<4.0' if x<=4.0 else '<4.0x<6.0' if 4.0<x<6.0 else '>6.0')

# %% [raw]
# df['wacr']=df['Weighted average call rate'].apply(lambda x: '<5' if x<=5 else '5 to 5.30' if 5.0<x<=5.30
#                                                   else '5.30 to 5.60' if 5.30<x<=5.60 else '5.60 to 5.90' if 5.60<x<=5.90
#                                                   else '5.90 to 6.20' if 5.90<x<=6.20 else '6.20 to 6.50' if 6.20<x<=6.50
#                                                   else '6.50 to 6.80' if 6.80<x<=7.10 else '>7.10' )

# %%
df['wacr']=df['Weighted average call rate'].apply(lambda x: '<4.0' if x<4.0 else '<4.0x<6.0' if 4.0<x<6.0 else '>6.0')

# %% [raw]
# df['rer']=df['realErRate'].apply(lambda x: '<=98' if x<=98.0 else '98 to 99' if 98.0<x<=99.0 else '99 to 100' if 99.0<x<=100.0
#                              else '100 to 101' if 100.0<x<=101.0 else '>101')

# %%
df['rer']=df['realErRate'].apply(lambda x: '<=0' if x<=0 else '0 to 2' if 0<x<=2 else '2 to 4' if 2<x<=4
                             else '>4')

# %% [raw]
# df['gpr']=df['GPrRate'].apply(lambda x: '<70' if x<=70 else '70 to 90' if 70<x<=90 else '90 to 110' if 90<x<=110
#                           else '110 to 130' if 110<x<=130 else '130 to 150' if 130<x<=150 else '150 to 170' if 150<x<=170
#                           else '170 to 190' if 170<x<=190 else '>190')

# %%
df['gpr']=df['GPrRate'].apply(lambda x: '<0' if x<=0 else '0 to 10' if 0<x<=15 else '>15')

# %% [raw]
# df['cpi']=df['CPI'].apply(lambda x: '<2' if x<=2.0 else '2 to 5' if 2<x<=5.0 else '>5' )

# %%
df['cpi']=df['CPI'].apply(lambda x: '<2' if x<=2.0 else '2 to 3' if 2<x<=3.0 else  '3 to 4' if 3<x<=4.0 else '4 to 5' if 4<x<=5.0 else '5 to 6' if 5<x<=6.0
                          else '>6'  )

# %% [raw]
# df['cgr']=df['creditgrowth'].apply(lambda x: '<=4' if x<=4 else '4 to 6' if 4<x<=6 else '6 to 8' if 6<x<=8
#                                     else '8 to 10' if 8<x<=10 else '10 to 12' if 10<x<=12 else '12 to 14' if 12<x<=14 else '>14')

# %%
df['cgr']=df['creditgrowth'].apply(lambda x: '<6.5' if x<=6.5 else '6.5 to 9' if 6<x<=9 else '>9')

# %% [raw]
# df['astgr']=df['assetgrowth'].apply(lambda x: '<-20' if x<=-20 else '-20 to -10' if -20<x<=-10 else '-10 to 0' if -10<x<=0 else '0 to 10' if 0<x<=10
#                                     else '10 to 20' if 10<x<=20 else '20 to 30' if 20<x<=30 else '>30')

# %%
df['astgr']=df['assetgrowth'].apply(lambda x: '<2' if x<=2 else '2 to 10' if 2<x<=10 else '>10')

# %%
df['gdpgr']=df['gdpRate'].apply(lambda x: '<=0' if x<=0 else '0 to 2' if 0<x<=2 else '2 to 4' if 2<x<=4
                                else '4 to 4.5' if 4<x<=4.5 else '4.5 to 5' if 4.5<x<=5 else '5 to 5.5' if 5<x<=5.5
                                else '5.5 to 6' if 5.5<x<=6 else '6 to 6.5' if 6<x<=6.5 else '6.5 to 7' if 6.5<x<=7
                                else '7 to 7.5' if 7<x<=7.5 else '7.5 to 8' if 7.5<x<=8 else '8 to 8.5' if 8<x<=8.5
                                else '8.5 to 9' if 8.5<x<=9 else '>9')

# %% [raw]
# df['gdpgr']=df['gdpRate'].apply(lambda x: '<5' if x<=5 else '5 to 7' if 0<x<=7 else '>7')

# %% [raw]
# df['invgr'] = df['investmentRate'].apply(lambda x: '<=0' if x<=0 else '0 to 5' if 0<x<=5 else '5 to 10' if 5<x<=10
#                                     else '10 to 15' if 10<x<=15 else '15 to 20' if 15<x<=20 else '20 to 25' if 20<x<=25 else '>')

# %%
df['invgr'] = df['investmentRate'].apply(lambda x: '<=5' if x<=5 else '5 to 10' if 5<x<=10 else '>10')

# %% [raw]
# df['nxpgr'] = df['netexportRate'].apply(lambda x: '<=-17' if x<=-17 else '-17 to 12' if -17<x<=12 else '12 to 40' if 12<x<=40
#                                     else '>40')

# %%
df['nxpgr'] = df['netexportRate'].apply(lambda x: '<=0' if x<=0 else '0 to 12' if 0<x<=12 else '12 to 40' if 12<x<=40
                                    else '>40')

# %%
df
# Out:
#             Weighted average call rate  policy rate   CPI  creditgrowth  \
# Date
# 2015-01-01                        7.89         7.75  5.19      9.263881
# 2015-02-01                        7.69         7.75  5.37      8.877285
# 2015-03-01                        7.58         7.50  5.25      9.047648
# 2015-04-01                        7.44         7.50  4.87      9.308951
# 2015-05-01                        7.47         7.50  5.01      9.349022
# ...                                ...          ...   ...           ...
# 2022-05-01                        4.09         4.00  7.00     11.434577
# 2022-06-01                        4.61         4.40  7.00     12.252593
# 2022-07-01                        5.04         4.90  6.70     13.370371
# 2022-08-01                        5.10         4.90  7.00     14.324775
# 2022-09-01                        5.52         5.40  7.41     19.029013
#
#             assetgrowth   gdpRate  investmentRate  netexportRate  realErRate  \
# Date
# ...

# %%
df.columns
# Out:
# Index(['Weighted average call rate', 'policy rate', 'CPI', 'creditgrowth',
#        'assetgrowth', 'gdpRate', 'investmentRate', 'netexportRate',
#        'realErRate', 'GPrRate', 'pr', 'wacr', 'rer', 'gpr', 'cpi', 'cgr',
#        'astgr', 'gdpgr', 'invgr', 'nxpgr'],
#       dtype='object')

# %%
df.drop(['Weighted average call rate', 'policy rate',  'CPI', 'creditgrowth', 'assetgrowth', 'gdpRate', 'investmentRate', 'netexportRate',
         'realErRate', 'GPrRate'] , axis = 1, inplace = True)

# %% [markdown]
# # Manual structure learning

# %%
df
# Out:
#                     pr       wacr     rer      gpr     cpi       cgr    astgr  \
# Date
# 2015-01-01  7.5 to 8.0       >6.0      >4      >15  5 to 6        >9      >10
# 2015-02-01  7.5 to 8.0       >6.0      >4      >15  5 to 6  6.5 to 9      >10
# 2015-03-01  7.0 to 7.5       >6.0      >4       <0  5 to 6        >9      >10
# 2015-04-01  7.0 to 7.5       >6.0      >4  0 to 10  4 to 5        >9      >10
# 2015-05-01  7.0 to 7.5       >6.0      >4       <0  5 to 6        >9      >10
# ...                ...        ...     ...      ...     ...       ...      ...
# 2022-05-01         <=4  <4.0x<6.0  2 to 4      >15      >6        >9  2 to 10
# 2022-06-01  4.0 to 4.5  <4.0x<6.0  0 to 2      >15      >6        >9  2 to 10
# 2022-07-01  4.5 to 5.0  <4.0x<6.0  0 to 2      >15      >6        >9  2 to 10
# 2022-08-01  4.5 to 5.0  <4.0x<6.0  0 to 2      >15      >6        >9  2 to 10
# 2022-09-01  5.0 to 5.5  <4.0x<6.0  0 to 2      >15      >6        >9       <2
#
# ...

# %%
df.columns
# Out:
# Index(['pr', 'wacr', 'rer', 'gpr', 'cpi', 'cgr', 'astgr', 'gdpgr', 'invgr',
#        'nxpgr'],
#       dtype='object')

# %%
from pgmpy.models import BayesianModel

model = BayesianModel([('pr', 'wacr'),   ('wacr', 'invgr'),   ('invgr', 'gdpgr'),
                       ('gdpgr', 'cpi'), ('pr', 'rer'), ('rer', 'nxpgr'), ('nxpgr', 'gdpgr'), ('pr', 'cgr'), ('cgr', 'gdpgr'),
                       ('cgr', 'cpi'),('wacr', 'astgr'), ('astgr', 'gdpgr'), ('cgr', 'astgr'), ('rer', 'cpi'), ('rer', 'astgr'),
                       ('rer', 'cgr'),  ('wacr', 'rer'), ('wacr', 'cpi'),('gpr', 'cpi'), ('astgr', 'cpi')])
# Out:
# C:\Users\NIYAZ AHMED\anaconda3\lib\site-packages\pgmpy\models\BayesianModel.py:8: FutureWarning: BayesianModel has been renamed to BayesianNetwork. Please use BayesianNetwork class, BayesianModel will be removed in future.
#   warnings.warn(

# %%
from pgmpy.models import BayesianModel

model_complex = BayesianModel([('pr', 'wacr'),   ('wacr', 'invgr'),   ('invgr', 'gdpgr'),
                       ('gdpgr', 'cpi'), ('wacr', 'rer'), ('rer', 'nxpgr'), ('nxpgr', 'gdpgr'), ('wacr', 'cgr'), ('cgr', 'gdpgr'),
                       ('wacr', 'astgr'), ('astgr', 'gdpgr')])

# %%
model_int  = BayesianModel([('pr', 'wacr'),   ('wacr', 'invgr'),   ('invgr', 'gdpgr'),
                       ('gdpgr', 'cpi')])

# %%
model_ex =  BayesianModel([('pr', 'wacr'), ('wacr', 'rer'), ('rer', 'nxpgr'), ('nxpgr', 'gdpgr'),('gdpgr', 'cpi')])

# %%
model_crdt = BayesianModel([('pr', 'wacr'), ('wacr', 'cgr'), ('cgr', 'gdpgr'),('gdpgr', 'cpi')])

# %%
model_astgr = BayesianModel([('pr', 'wacr'), ('wacr', 'astgr'), ('astgr', 'gdpgr'),('gdpgr', 'cpi')])

# %%
df_int = df[['pr', 'wacr', 'invgr', 'gdpgr', 'cpi']]

# %%
df_ex = df[['pr', 'wacr', 'rer', 'nxpgr', 'gdpgr', 'cpi']]

# %%
df_crdt = df[['pr', 'wacr', 'cgr', 'gdpgr', 'cpi']]

# %%
df_astgr = df[['pr', 'wacr', 'astgr', 'gdpgr', 'cpi']]

# %%
(model_int)

# %% [markdown]
# # Bayesian Priori Fitting

# %%
from pgmpy.estimators import BayesianEstimator, MaximumLikelihoodEstimator
from IPython.core.display import display, HTML

# disable text wrapping in output cell
display(HTML("<style>div.output_area pre {white-space: pre;}</style>"))

model_int.cpds = []
model_int.fit(data=df_int,
          estimator=BayesianEstimator,
          prior_type="BDeu",
          complete_samples_only=False)

print(f'Check model: {model_int.check_model()}\n')
for cpd in model_int.get_cpds():
    print(f'CPT of {cpd.variable}:')
    print(cpd, '\n')
# Out:
# <style>div.output_area pre {white-space: pre;}</style>
# Check model: True
#
# CPT of pr:
# +----------------+-----------+
# | pr(4.0 to 4.5) | 0.0362812 |
# +----------------+-----------+
# | pr(4.5 to 5.0) | 0.0260771 |
# +----------------+-----------+
# | pr(5.0 to 5.5) | 0.0873016 |
# +----------------+-----------+
# | pr(5.5 to 6.0) | 0.148526  |
# +----------------+-----------+
# | pr(6 to 6.5)   | 0.270975  |
# +----------------+-----------+
# | pr(6.5 to 7.0) | 0.0668934 |
# +----------------+-----------+
# | pr(7.0 to 7.5) | 0.0770975 |
# +----------------+-----------+
# | pr(7.5 to 8.0) | 0.0260771 |
# +----------------+-----------+
# | pr(<=4)        | 0.260771  |
# +----------------+-----------+
#
# CPT of wacr:
# +-----------------+----------------------+-----+---------------------+----------------------+
# | pr              | pr(4.0 to 4.5)       | ... | pr(7.5 to 8.0)      | pr(<=4)              |
# ...

# %%
model_int.fit??

# %%
from pgmpy.estimators import BayesianEstimator, MaximumLikelihoodEstimator
from IPython.core.display import display, HTML

# disable text wrapping in output cell
display(HTML("<style>div.output_area pre {white-space: pre;}</style>"))

model_ex.cpds = []
model_ex.fit(data=df_ex,
          estimator=BayesianEstimator,
          prior_type="BDeu",
          complete_samples_only=False)

print(f'Check model: {model_ex.check_model()}\n')
for cpd in model_ex.get_cpds():
    print(f'CPT of {cpd.variable}:')
    print(cpd, '\n')
# Out:
# <style>div.output_area pre {white-space: pre;}</style>
# Check model: True
#
# CPT of pr:
# +----------------+-----------+
# | pr(4.0 to 4.5) | 0.0362812 |
# +----------------+-----------+
# | pr(4.5 to 5.0) | 0.0260771 |
# +----------------+-----------+
# | pr(5.0 to 5.5) | 0.0873016 |
# +----------------+-----------+
# | pr(5.5 to 6.0) | 0.148526  |
# +----------------+-----------+
# | pr(6 to 6.5)   | 0.270975  |
# +----------------+-----------+
# | pr(6.5 to 7.0) | 0.0668934 |
# +----------------+-----------+
# | pr(7.0 to 7.5) | 0.0770975 |
# +----------------+-----------+
# | pr(7.5 to 8.0) | 0.0260771 |
# +----------------+-----------+
# | pr(<=4)        | 0.260771  |
# +----------------+-----------+
#
# CPT of wacr:
# +-----------------+----------------------+-----+---------------------+----------------------+
# | pr              | pr(4.0 to 4.5)       | ... | pr(7.5 to 8.0)      | pr(<=4)              |
# ...

# %%
from pgmpy.estimators import BayesianEstimator, MaximumLikelihoodEstimator
from IPython.core.display import display, HTML

# disable text wrapping in output cell
display(HTML("<style>div.output_area pre {white-space: pre;}</style>"))

model_crdt.cpds = []
model_crdt.fit(data=df_crdt,
          estimator=BayesianEstimator,
          prior_type="BDeu",
          complete_samples_only=False)

print(f'Check model: {model_crdt.check_model()}\n')
for cpd in model_crdt.get_cpds():
    print(f'CPT of {cpd.variable}:')
    print(cpd, '\n')
# Out:
# <style>div.output_area pre {white-space: pre;}</style>
# Check model: True
#
# CPT of pr:
# +----------------+-----------+
# | pr(4.0 to 4.5) | 0.0362812 |
# +----------------+-----------+
# | pr(4.5 to 5.0) | 0.0260771 |
# +----------------+-----------+
# | pr(5.0 to 5.5) | 0.0873016 |
# +----------------+-----------+
# | pr(5.5 to 6.0) | 0.148526  |
# +----------------+-----------+
# | pr(6 to 6.5)   | 0.270975  |
# +----------------+-----------+
# | pr(6.5 to 7.0) | 0.0668934 |
# +----------------+-----------+
# | pr(7.0 to 7.5) | 0.0770975 |
# +----------------+-----------+
# | pr(7.5 to 8.0) | 0.0260771 |
# +----------------+-----------+
# | pr(<=4)        | 0.260771  |
# +----------------+-----------+
#
# CPT of wacr:
# +-----------------+----------------------+-----+---------------------+----------------------+
# | pr              | pr(4.0 to 4.5)       | ... | pr(7.5 to 8.0)      | pr(<=4)              |
# ...

# %%
from pgmpy.estimators import BayesianEstimator, MaximumLikelihoodEstimator
from IPython.core.display import display, HTML

# disable text wrapping in output cell
display(HTML("<style>div.output_area pre {white-space: pre;}</style>"))

model_astgr.cpds = []
model_astgr.fit(data=df_astgr,
          estimator=BayesianEstimator,
          prior_type="BDeu",
          complete_samples_only=False)

print(f'Check model: {model_astgr.check_model()}\n')
for cpd in model_astgr.get_cpds():
    print(f'CPT of {cpd.variable}:')
    print(cpd, '\n')
# Out:
# <style>div.output_area pre {white-space: pre;}</style>
# Check model: True
#
# CPT of pr:
# +----------------+-----------+
# | pr(4.0 to 4.5) | 0.0362812 |
# +----------------+-----------+
# | pr(4.5 to 5.0) | 0.0260771 |
# +----------------+-----------+
# | pr(5.0 to 5.5) | 0.0873016 |
# +----------------+-----------+
# | pr(5.5 to 6.0) | 0.148526  |
# +----------------+-----------+
# | pr(6 to 6.5)   | 0.270975  |
# +----------------+-----------+
# | pr(6.5 to 7.0) | 0.0668934 |
# +----------------+-----------+
# | pr(7.0 to 7.5) | 0.0770975 |
# +----------------+-----------+
# | pr(7.5 to 8.0) | 0.0260771 |
# +----------------+-----------+
# | pr(<=4)        | 0.260771  |
# +----------------+-----------+
#
# CPT of wacr:
# +-----------------+----------------------+-----+---------------------+----------------------+
# | pr              | pr(4.0 to 4.5)       | ... | pr(7.5 to 8.0)      | pr(<=4)              |
# ...

# %%
from pgmpy.estimators import BayesianEstimator, MaximumLikelihoodEstimator
from IPython.core.display import display, HTML

# disable text wrapping in output cell
display(HTML("<style>div.output_area pre {white-space: pre;}</style>"))

model_complex.cpds = []
model_complex.fit(data=df,
          estimator=BayesianEstimator,
          prior_type="BDeu",
          complete_samples_only=False)

print(f'Check model: {model_complex.check_model()}\n')
for cpd in model_complex.get_cpds():
    print(f'CPT of {cpd.variable}:')
    print(cpd, '\n')
# Out:
# <style>div.output_area pre {white-space: pre;}</style>
# Check model: True
#
# CPT of pr:
# +----------------+-----------+
# | pr(4.0 to 4.5) | 0.0362812 |
# +----------------+-----------+
# | pr(4.5 to 5.0) | 0.0260771 |
# +----------------+-----------+
# | pr(5.0 to 5.5) | 0.0873016 |
# +----------------+-----------+
# | pr(5.5 to 6.0) | 0.148526  |
# +----------------+-----------+
# | pr(6 to 6.5)   | 0.270975  |
# +----------------+-----------+
# | pr(6.5 to 7.0) | 0.0668934 |
# +----------------+-----------+
# | pr(7.0 to 7.5) | 0.0770975 |
# +----------------+-----------+
# | pr(7.5 to 8.0) | 0.0260771 |
# +----------------+-----------+
# | pr(<=4)        | 0.260771  |
# +----------------+-----------+
#
# CPT of wacr:
# +-----------------+----------------------+-----+---------------------+----------------------+
# | pr              | pr(4.0 to 4.5)       | ... | pr(7.5 to 8.0)      | pr(<=4)              |
# ...

# %%
from pgmpy.estimators import BayesianEstimator, MaximumLikelihoodEstimator
from IPython.core.display import display, HTML

# disable text wrapping in output cell
display(HTML("<style>div.output_area pre {white-space: pre;}</style>"))

model.cpds = []
model.fit(data=df,
          estimator=BayesianEstimator,
          prior_type="BDeu")

print(f'Check model: {model.check_model()}\n')
for cpd in model.get_cpds():
    print(f'CPT of {cpd.variable}:')
    print(cpd, '\n')
# Out:
# <style>div.output_area pre {white-space: pre;}</style>
# Check model: True
#
# CPT of pr:
# +----------------+-----------+
# | pr(4.0 to 4.5) | 0.0362812 |
# +----------------+-----------+
# | pr(4.5 to 5.0) | 0.0260771 |
# +----------------+-----------+
# | pr(5.0 to 5.5) | 0.0873016 |
# +----------------+-----------+
# | pr(5.5 to 6.0) | 0.148526  |
# +----------------+-----------+
# | pr(6 to 6.5)   | 0.270975  |
# +----------------+-----------+
# | pr(6.5 to 7.0) | 0.0668934 |
# +----------------+-----------+
# | pr(7.0 to 7.5) | 0.0770975 |
# +----------------+-----------+
# | pr(7.5 to 8.0) | 0.0260771 |
# +----------------+-----------+
# | pr(<=4)        | 0.260771  |
# +----------------+-----------+
#
# CPT of wacr:
# +-----------------+----------------------+-----+---------------------+----------------------+
# | pr              | pr(4.0 to 4.5)       | ... | pr(7.5 to 8.0)      | pr(<=4)              |
# ...

# %%
df.columns
# Out:
# Index(['pr', 'wacr', 'rer', 'gpr', 'cpi', 'cgr', 'astgr', 'gdpgr', 'invgr',
#        'nxpgr'],
#       dtype='object')

# %% [raw]
# # Printing a CPD with it's state names defined.
# print(model.get_cpds('pr'))

# %% [raw]
# # Getting all the local independencies in the network.
# model.local_independencies(['pr'])

# %% [raw]
# # Getting all the local independencies in the network.
# model.local_independencies(['pr', 'cgr', 'wacr', 'rer', 'astgr', 'gpr', 'cpi', 'gdpgr', 'nxpgr', 'invgr'])

# %% [raw]
# nodes = ['pr', 'cgr', 'wacr', 'rer', 'astgr', 'gpr', 'cpi', 'gdpgr', 'nxpgr', 'invgr']

# %% [raw]
# print(f'There can be made {len(model.get_independencies().get_assertions())}',
#       'valid independence assertions with respect to the all possible given evidence.')
# print('For instance, any node in the network is independent of its non-descendents given its parents (local semantics):\n',
#       f'\n{model.local_independencies(nodes)}\n')

# %%
nodes = ['pr',  'wacr',  'cpi', 'gdpgr',  'invgr']

# %%
print(f'There can be made {len(model_int.get_independencies().get_assertions())}',
      'valid independence assertions with respect to the all possible given evidence.')
print('For instance, any node in the network is independent of its non-descendents given its parents (local semantics):\n',
      f'\n{model_int.local_independencies(nodes)}\n')
# Out:
# There can be made 45 valid independence assertions with respect to the all possible given evidence.
# For instance, any node in the network is independent of its non-descendents given its parents (local semantics):
#
# (cpi ⟂ wacr, invgr, pr | gdpgr)
# (gdpgr ⟂ wacr, pr | invgr)
# (invgr ⟂ pr | wacr)

# %% [markdown]
# #### Active Trail

# %% [raw]
# print(f'There can be made {len(model.get_independencies().get_assertions())}',
#       'valid independence assertions with respect to the all possible given evidence.')
# print('For instance, any node in the network is independent of its non-descendents given its parents (local semantics):\n',
#       f'\n{model.local_independencies(nodes)}\n')
#
# def active_trails_of(query, evidence):
#     active = model.active_trail_nodes(query, observed=evidence).get(query)
#     active.remove(query)
#     if active:
#         if evidence:
#             print(f'Active trails between \'{query}\' and {active} given the evidence {set(evidence)}.')
#         else:
#             print(f'Active trails between \'{query}\' and {active} given no evidence.')
#     else:
#         print(f'No active trails for \'{query}\' given the evidence {set(evidence)}.')
#
# #def markov_blanket_of(node):
#     #print(f'Markov blanket of \'{node}\' is {set(model.get_markov_blanket(node))}')
#
# active_trails_of(query='rer', evidence=[])
# active_trails_of(query='rer', evidence=['cgr'])
# #active_trails_of(query='FFEC', evidence=['EC', 'CO2'])
# #active_trails_of(query='EI', evidence=['EC'])
# #active_trails_of(query='CH4', evidence=['EC', 'FFEC'])
# print()

# %% [raw]
# def independent_assertions_score_function(node):
#     return len([a for a in model.get_independencies().get_assertions() if node in a.event1])
#
# def evidence_assertions_score_function(node):
#     return len([a for a in model.get_independencies().get_assertions() if node in a.event3])
#
# def update(assertion_dict, node, score_function):
#     tmp_score = score_function(node)
#     if tmp_score == assertion_dict["max"]["score"]:
#         assertion_dict["max"]["nodes"].append(node)
#     elif tmp_score > assertion_dict["max"]["score"]:
#         assertion_dict["max"]["nodes"] = [node]
#         assertion_dict["max"]["score"] = tmp_score
#     if tmp_score == assertion_dict["min"]["score"]:
#         assertion_dict["min"]["nodes"].append(node)
#     elif tmp_score < assertion_dict["min"]["score"]:
#         assertion_dict["min"]["nodes"] = [node]
#         assertion_dict["min"]["score"] = tmp_score
#
# if len(nodes) > 1:
#     independent_init = independent_assertions_score_function(nodes[0])
#     independent_dict = {"max": {"nodes": [nodes[0]], "score": independent_init},
#                        "min": {"nodes": [nodes[0]], "score": independent_init}}
#     evidence_init = evidence_assertions_score_function(nodes[0])
#     evidence_dict = {"max": {"nodes": [nodes[0]], "score": evidence_init},
#                     "min": {"nodes": [nodes[0]], "score": evidence_init}}
#     for node in nodes[1:]:
#         update(independent_dict, node, independent_assertions_score_function)
#         update(evidence_dict, node, evidence_assertions_score_function)
#
# print(f'Nodes which appear most ({independent_dict["max"]["score"]} times) in independence assertions',
#       f'as independent variable are:\n{set(independent_dict["max"]["nodes"])}')
# print(f'Nodes which appear least ({independent_dict["min"]["score"]} times) in independence assertions',
#       f'as independent variable are:\n{set(independent_dict["min"]["nodes"])}')
# print(f'Nodes which appear most ({evidence_dict["max"]["score"]} times) in independence assertions',
#       f'as evidence are:\n{set(evidence_dict["max"]["nodes"])}')
# print(f'Nodes which appear least ({evidence_dict["min"]["score"]} times) in independence assertions',
#       f'as evidence are:\n{set(evidence_dict["min"]["nodes"])}')

# %% [raw]
# from pgmpy.independencies.Independencies import IndependenceAssertion
#
# def check_assertion(model, independent, from_variables, evidence):
#     assertion = IndependenceAssertion(independent, from_variables, evidence)
#     result = False
#     for a in model.get_independencies().get_assertions():
#         if frozenset(assertion.event1) == a.event1 and assertion.event2 <= a.event2 and frozenset(assertion.event3) == a.event3:
#             result = True
#             break
#     print(f'{assertion}: {result}')
#
# check_assertion(model, independent=['gpr'], from_variables=['wacr'], evidence=[])
# #check_assertion(model, independent=['EI'], from_variables=["FFEC", "REC", "GDP", "Pop", "Urb"], evidence=['EC'])
# #check_assertion(model, independent=['EC'], from_variables=["CH4"], evidence=['FFEC'])
# #check_assertion(model, independent=['EC'], from_variables=["CH4"], evidence=['FFEC', 'REC'])
# #check_assertion(model, independent=['FFEC'], from_variables=["REC"], evidence=['EC'])
# #check_assertion(model, independent=['FFEC'], from_variables=["REC"], evidence=['EC', 'CO2'])
# #check_assertion(model, independent=['CH4'], from_variables=["CO2"], evidence=['FFEC'])
# #check_assertion(model, independent=['CH4'], from_variables=["CO2"], evidence=['FFEC', 'REC'])

# %% [raw]
# from pgmpy.independencies.Independencies import IndependenceAssertion
#
# def check_assertion(model, independent, from_variables, evidence):
#     assertion = IndependenceAssertion(independent, from_variables, evidence)
#     result = False
#     for a in model.get_independencies().get_assertions():
#         if frozenset(assertion.event1) == a.event1 and assertion.event2 <= a.event2 and frozenset(assertion.event3) == a.event3:
#             result = True
#             break
#     print(f'{assertion}: {result}')
#
# check_assertion(model_1, independent=['gpr'], from_variables=['wacr'], evidence=[])
# #check_assertion(model, independent=['EI'], from_variables=["FFEC", "REC", "GDP", "Pop", "Urb"], evidence=['EC'])
# #check_assertion(model, independent=['EC'], from_variables=["CH4"], evidence=['FFEC'])
# #check_assertion(model, independent=['EC'], from_variables=["CH4"], evidence=['FFEC', 'REC'])
# #check_assertion(model, independent=['FFEC'], from_variables=["REC"], evidence=['EC'])
# #check_assertion(model, independent=['FFEC'], from_variables=["REC"], evidence=['EC', 'CO2'])
# #check_assertion(model, independent=['CH4'], from_variables=["CO2"], evidence=['FFEC'])
# #check_assertion(model, independent=['CH4'], from_variables=["CO2"], evidence=['FFEC', 'REC'])

# %% [markdown]
# # Inferences

# %%
from pgmpy.inference import VariableElimination
import time

def query_report(infer, variables, evidence=None, elimination_order="MinFill", show_progress=False, desc=""):
    if desc:
        print(desc)
    start_time = time.time()
    print(infer.query(variables=variables,
                      evidence=evidence,
                      elimination_order=elimination_order,
                      show_progress=show_progress))
    print(f'--- Query executed in {time.time() - start_time:0,.4f} seconds ---\n')

def get_ordering(infer, variables, evidence=None, elimination_order="MinFill", show_progress=False, desc=""):
    start_time = time.time()
    ordering = infer._get_elimination_order(variables=variables,
                                        evidence=evidence,
                                        elimination_order=elimination_order,
                                        show_progress=show_progress)
    if desc:
        print(desc, ordering, sep='\n')
        print(f'--- Ordering found in {time.time() - start_time:0,.4f} seconds ---\n')
    return ordering

def padding(heuristic):
    return (heuristic + ":").ljust(16)

def compare_all_ordering(infer, variables, evidence=None, show_progress=False):
    ord_dict = {
        "MinFill": get_ordering(infer, variables, evidence, "MinFill", show_progress),
        "MinNeighbors": get_ordering(infer, variables, evidence, "MinNeighbors", show_progress),
        "MinWeight": get_ordering(infer, variables, evidence, "MinWeight", show_progress),
        "WeightedMinFill": get_ordering(infer, variables, evidence, "WeightedMinFill", show_progress)
    }
    if not evidence:
        pre = f'elimination order found for probability query of {variables} with no evidence:'
    else:
        pre = f'elimination order found for probability query of {variables} with evidence {evidence}:'
    if ord_dict["MinFill"] == ord_dict["MinNeighbors"] and ord_dict["MinFill"] == ord_dict["MinWeight"] and ord_dict["MinFill"] == ord_dict["WeightedMinFill"]:
        print(f'All heuristics find the same {pre}.\n{ord_dict["MinFill"]}\n')
    else:
        print(f'Different {pre}')
        for heuristic, order in ord_dict.items():
            print(f'{padding(heuristic)} {order}')
        print()

infer = VariableElimination(model)

var = ['cpi']
heuristic = "MinNeighbors"
ordering = get_ordering(infer, variables=var, elimination_order=heuristic,
                        desc=f'Elimination order for {var} with no evidence computed through {heuristic} heuristic:')
query_report(infer, variables=var, elimination_order=ordering,
             desc=f'Probability query of {var} with no evidence through precomputed elimination order:')
query_report(infer, variables=var, elimination_order=list(reversed(ordering)),
             desc=f'Probability query of {var} with no evidence through dummy elimination order:')
compare_all_ordering(infer, variables=var)

var = ['cpi']
ev = {'pr': '<=4'}
heuristic = "MinFill"
query_report(infer, variables=var, evidence=ev, elimination_order=heuristic,
             desc=f'Probability query of {var} with evidence {ev} computed through {heuristic} heuristic:')
compare_all_ordering(infer, variables=var, evidence=ev)
heuristic = "MinNeighbors"
query_report(infer, variables=var, evidence=ev, elimination_order=heuristic,
             desc=f'Probability query of {var} with evidence {ev} computed through {heuristic} heuristic:')
# Out:
# Elimination order for ['cpi'] with no evidence computed through MinNeighbors heuristic:
# ['pr', 'nxpgr', 'invgr', 'cgr', 'gdpgr', 'astgr', 'gpr', 'rer', 'wacr']
# --- Ordering found in 0.0158 seconds ---
#
# Probability query of ['cpi'] with no evidence through precomputed elimination order:
# +-------------+------------+
# | cpi         |   phi(cpi) |
# +=============+============+
# | cpi(2 to 3) |     0.1583 |
# +-------------+------------+
# | cpi(3 to 4) |     0.1600 |
# +-------------+------------+
# | cpi(4 to 5) |     0.1747 |
# +-------------+------------+
# | cpi(5 to 6) |     0.1876 |
# +-------------+------------+
# | cpi(<2)     |     0.1473 |
# +-------------+------------+
# | cpi(>6)     |     0.1721 |
# +-------------+------------+
# --- Query executed in 0.0219 seconds ---
#
# Probability query of ['cpi'] with no evidence through dummy elimination order:
# +-------------+------------+
# | cpi         |   phi(cpi) |
# +=============+============+
# ...

# %%
df.pr.value_counts()
# Out:
# 6 to 6.5      26
# <=4           25
# 5.5 to 6.0    14
# 5.0 to 5.5     8
# 7.0 to 7.5     7
# 6.5 to 7.0     6
# 4.0 to 4.5     3
# 4.5 to 5.0     2
# 7.5 to 8.0     2
# Name: pr, dtype: int64

# %%
from pgmpy.inference import VariableElimination
import time

def query_report(infer, variables, evidence=None, elimination_order="MinFill", show_progress=False, desc=""):
    if desc:
        print(desc)
    start_time = time.time()
    print(infer.query(variables=variables,
                      evidence=evidence,
                      elimination_order=elimination_order,
                      show_progress=show_progress))
    print(f'--- Query executed in {time.time() - start_time:0,.4f} seconds ---\n')

def get_ordering(infer, variables, evidence=None, elimination_order="MinFill", show_progress=False, desc=""):
    start_time = time.time()
    ordering = infer._get_elimination_order(variables=variables,
                                        evidence=evidence,
                                        elimination_order=elimination_order,
                                        show_progress=show_progress)
    if desc:
        print(desc, ordering, sep='\n')
        print(f'--- Ordering found in {time.time() - start_time:0,.4f} seconds ---\n')
    return ordering

def padding(heuristic):
    return (heuristic + ":").ljust(16)

def compare_all_ordering(infer, variables, evidence=None, show_progress=False):
    ord_dict = {
        "MinFill": get_ordering(infer, variables, evidence, "MinFill", show_progress),
        "MinNeighbors": get_ordering(infer, variables, evidence, "MinNeighbors", show_progress),
        "MinWeight": get_ordering(infer, variables, evidence, "MinWeight", show_progress),
        "WeightedMinFill": get_ordering(infer, variables, evidence, "WeightedMinFill", show_progress)
    }
    if not evidence:
        pre = f'elimination order found for probability query of {variables} with no evidence:'
    else:
        pre = f'elimination order found for probability query of {variables} with evidence {evidence}:'
    if ord_dict["MinFill"] == ord_dict["MinNeighbors"] and ord_dict["MinFill"] == ord_dict["MinWeight"] and ord_dict["MinFill"] == ord_dict["WeightedMinFill"]:
        print(f'All heuristics find the same {pre}.\n{ord_dict["MinFill"]}\n')
    else:
        print(f'Different {pre}')
        for heuristic, order in ord_dict.items():
            print(f'{padding(heuristic)} {order}')
        print()

infer_complex = VariableElimination(model_complex)

var = ['cpi']
heuristic = "MinNeighbors"
ordering = get_ordering(infer_complex, variables=var, elimination_order=heuristic,
                        desc=f'Elimination order for {var} with no evidence computed through {heuristic} heuristic:')
query_report(infer_complex, variables=var, elimination_order=ordering,
             desc=f'Probability query of {var} with no evidence through precomputed elimination order:')
query_report(infer_complex, variables=var, elimination_order=list(reversed(ordering)),
             desc=f'Probability query of {var} with no evidence through dummy elimination order:')
compare_all_ordering(infer_complex, variables=var)

var = ['cpi']
ev = {'pr': '<=4' }
heuristic = "MinFill"
query_report(infer_complex, variables=var, evidence=ev, elimination_order=heuristic,
             desc=f'Probability query of {var} with evidence {ev} computed through {heuristic} heuristic:')
compare_all_ordering(infer_complex, variables=var, evidence=ev)
heuristic = "MinNeighbors"
query_report(infer_complex, variables=var, evidence=ev, elimination_order=heuristic,
             desc=f'Probability query of {var} with evidence {ev} computed through {heuristic} heuristic:')
# Out:
# Elimination order for ['cpi'] with no evidence computed through MinNeighbors heuristic:
# ['pr', 'rer', 'wacr', 'cgr', 'nxpgr', 'astgr', 'invgr', 'gdpgr']
# --- Ordering found in 0.0106 seconds ---
#
# Probability query of ['cpi'] with no evidence through precomputed elimination order:
# +-------------+------------+
# | cpi         |   phi(cpi) |
# +=============+============+
# | cpi(2 to 3) |     0.0880 |
# +-------------+------------+
# | cpi(3 to 4) |     0.1926 |
# +-------------+------------+
# | cpi(4 to 5) |     0.2157 |
# +-------------+------------+
# | cpi(5 to 6) |     0.2555 |
# +-------------+------------+
# | cpi(<2)     |     0.0316 |
# +-------------+------------+
# | cpi(>6)     |     0.2167 |
# +-------------+------------+
# --- Query executed in 0.0204 seconds ---
#
# Probability query of ['cpi'] with no evidence through dummy elimination order:
# +-------------+------------+
# | cpi         |   phi(cpi) |
# +=============+============+
# ...

# %%
from pgmpy.inference import VariableElimination
import time

def query_report(infer, variables, evidence=None, elimination_order="MinFill", show_progress=False, desc=""):
    if desc:
        print(desc)
    start_time = time.time()
    print(infer.query(variables=variables,
                      evidence=evidence,
                      elimination_order=elimination_order,
                      show_progress=show_progress))
    print(f'--- Query executed in {time.time() - start_time:0,.4f} seconds ---\n')

def get_ordering(infer, variables, evidence=None, elimination_order="MinFill", show_progress=False, desc=""):
    start_time = time.time()
    ordering = infer._get_elimination_order(variables=variables,
                                        evidence=evidence,
                                        elimination_order=elimination_order,
                                        show_progress=show_progress)
    if desc:
        print(desc, ordering, sep='\n')
        print(f'--- Ordering found in {time.time() - start_time:0,.4f} seconds ---\n')
    return ordering

def padding(heuristic):
    return (heuristic + ":").ljust(16)

def compare_all_ordering(infer, variables, evidence=None, show_progress=False):
    ord_dict = {
        "MinFill": get_ordering(infer, variables, evidence, "MinFill", show_progress),
        "MinNeighbors": get_ordering(infer, variables, evidence, "MinNeighbors", show_progress),
        "MinWeight": get_ordering(infer, variables, evidence, "MinWeight", show_progress),
        "WeightedMinFill": get_ordering(infer, variables, evidence, "WeightedMinFill", show_progress)
    }
    if not evidence:
        pre = f'elimination order found for probability query of {variables} with no evidence:'
    else:
        pre = f'elimination order found for probability query of {variables} with evidence {evidence}:'
    if ord_dict["MinFill"] == ord_dict["MinNeighbors"] and ord_dict["MinFill"] == ord_dict["MinWeight"] and ord_dict["MinFill"] == ord_dict["WeightedMinFill"]:
        print(f'All heuristics find the same {pre}.\n{ord_dict["MinFill"]}\n')
    else:
        print(f'Different {pre}')
        for heuristic, order in ord_dict.items():
            print(f'{padding(heuristic)} {order}')
        print()

    
infer_int = VariableElimination(model_int)

var = ['cpi']
heuristic = "MinNeighbors"
ordering = get_ordering(infer_int, variables=var, elimination_order=heuristic,
                        desc=f'Elimination order for {var} with no evidence computed through {heuristic} heuristic:')
query_report(infer_int, variables=var, elimination_order=ordering,
             desc=f'Probability query of {var} with no evidence through precomputed elimination order:')
query_report(infer_int, variables=var, elimination_order=list(reversed(ordering)),
             desc=f'Probability query of {var} with no evidence through dummy elimination order:')
compare_all_ordering(infer_int, variables=var)

var = ['cpi']
ev = {'pr': '<=4', 'wacr': '<4.0' }
heuristic = "MinFill"
query_report(infer_int, variables=var, evidence=ev, elimination_order=heuristic,
             desc=f'Probability query of {var} with evidence {ev} computed through {heuristic} heuristic:')
compare_all_ordering(infer_int, variables=var, evidence=ev)
heuristic = "MinNeighbors"
query_report(infer_int, variables=var, evidence=ev, elimination_order=heuristic,
             desc=f'Probability query of {var} with evidence {ev} computed through {heuristic} heuristic:')
# Out:
# Elimination order for ['cpi'] with no evidence computed through MinNeighbors heuristic:
# ['pr', 'wacr', 'invgr', 'gdpgr']
# --- Ordering found in 0.0110 seconds ---
#
# Probability query of ['cpi'] with no evidence through precomputed elimination order:
# +-------------+------------+
# | cpi         |   phi(cpi) |
# +=============+============+
# | cpi(2 to 3) |     0.1003 |
# +-------------+------------+
# | cpi(3 to 4) |     0.1820 |
# +-------------+------------+
# | cpi(4 to 5) |     0.2126 |
# +-------------+------------+
# | cpi(5 to 6) |     0.2330 |
# +-------------+------------+
# | cpi(<2)     |     0.0289 |
# +-------------+------------+
# | cpi(>6)     |     0.2432 |
# +-------------+------------+
# --- Query executed in 0.0154 seconds ---
#
# Probability query of ['cpi'] with no evidence through dummy elimination order:
# +-------------+------------+
# | cpi         |   phi(cpi) |
# +=============+============+
# | cpi(2 to 3) |     0.1003 |
# ...

# %%
df.wacr.value_counts()
# Out:
# >6.0         40
# <4.0x<6.0    29
# <4.0         24
# Name: wacr, dtype: int64

# %%
from pgmpy.inference import VariableElimination
import time

def query_report(infer, variables, evidence=None, elimination_order="MinFill", show_progress=False, desc=""):
    if desc:
        print(desc)
    start_time = time.time()
    print(infer.query(variables=variables,
                      evidence=evidence,
                      elimination_order=elimination_order,
                      show_progress=show_progress))
    print(f'--- Query executed in {time.time() - start_time:0,.4f} seconds ---\n')

def get_ordering(infer, variables, evidence=None, elimination_order="MinFill", show_progress=False, desc=""):
    start_time = time.time()
    ordering = infer._get_elimination_order(variables=variables,
                                        evidence=evidence,
                                        elimination_order=elimination_order,
                                        show_progress=show_progress)
    if desc:
        print(desc, ordering, sep='\n')
        print(f'--- Ordering found in {time.time() - start_time:0,.4f} seconds ---\n')
    return ordering

def padding(heuristic):
    return (heuristic + ":").ljust(16)

def compare_all_ordering(infer, variables, evidence=None, show_progress=False):
    ord_dict = {
        "MinFill": get_ordering(infer, variables, evidence, "MinFill", show_progress),
        "MinNeighbors": get_ordering(infer, variables, evidence, "MinNeighbors", show_progress),
        "MinWeight": get_ordering(infer, variables, evidence, "MinWeight", show_progress),
        "WeightedMinFill": get_ordering(infer, variables, evidence, "WeightedMinFill", show_progress)
    }
    if not evidence:
        pre = f'elimination order found for probability query of {variables} with no evidence:'
    else:
        pre = f'elimination order found for probability query of {variables} with evidence {evidence}:'
    if ord_dict["MinFill"] == ord_dict["MinNeighbors"] and ord_dict["MinFill"] == ord_dict["MinWeight"] and ord_dict["MinFill"] == ord_dict["WeightedMinFill"]:
        print(f'All heuristics find the same {pre}.\n{ord_dict["MinFill"]}\n')
    else:
        print(f'Different {pre}')
        for heuristic, order in ord_dict.items():
            print(f'{padding(heuristic)} {order}')
        print()

    
infer_ex = VariableElimination(model_ex)

var = ['cpi']
heuristic = "MinNeighbors"
ordering = get_ordering(infer_ex, variables=var, elimination_order=heuristic,
                        desc=f'Elimination order for {var} with no evidence computed through {heuristic} heuristic:')
query_report(infer_ex, variables=var, elimination_order=ordering,
             desc=f'Probability query of {var} with no evidence through precomputed elimination order:')
query_report(infer_ex, variables=var, elimination_order=list(reversed(ordering)),
             desc=f'Probability query of {var} with no evidence through dummy elimination order:')
compare_all_ordering(infer_ex, variables=var)

var = ['cpi']
ev = {'pr': '<=4', 'wacr': '<4.0' }
heuristic = "MinFill"
query_report(infer_ex, variables=var, evidence=ev, elimination_order=heuristic,
             desc=f'Probability query of {var} with evidence {ev} computed through {heuristic} heuristic:')
compare_all_ordering(infer_ex, variables=var, evidence=ev)
heuristic = "MinNeighbors"
query_report(infer_ex, variables=var, evidence=ev, elimination_order=heuristic,
             desc=f'Probability query of {var} with evidence {ev} computed through {heuristic} heuristic:')
# Out:
# Elimination order for ['cpi'] with no evidence computed through MinNeighbors heuristic:
# ['pr', 'wacr', 'rer', 'nxpgr', 'gdpgr']
# --- Ordering found in 0.0028 seconds ---
#
# Probability query of ['cpi'] with no evidence through precomputed elimination order:
# +-------------+------------+
# | cpi         |   phi(cpi) |
# +=============+============+
# | cpi(2 to 3) |     0.1003 |
# +-------------+------------+
# | cpi(3 to 4) |     0.1820 |
# +-------------+------------+
# | cpi(4 to 5) |     0.2126 |
# +-------------+------------+
# | cpi(5 to 6) |     0.2330 |
# +-------------+------------+
# | cpi(<2)     |     0.0289 |
# +-------------+------------+
# | cpi(>6)     |     0.2432 |
# +-------------+------------+
# --- Query executed in 0.0086 seconds ---
#
# Probability query of ['cpi'] with no evidence through dummy elimination order:
# +-------------+------------+
# | cpi         |   phi(cpi) |
# +=============+============+
# | cpi(2 to 3) |     0.1003 |
# ...

# %%
get_ordering(infer_ex, variables=[])
# Out:
# ['pr', 'cpi', 'rer', 'wacr', 'nxpgr', 'gdpgr']

# %%
from pgmpy.inference import VariableElimination
import time

def query_report(infer, variables, evidence=None, elimination_order="MinFill", show_progress=False, desc=""):
    if desc:
        print(desc)
    start_time = time.time()
    print(infer.query(variables=variables,
                      evidence=evidence,
                      elimination_order=elimination_order,
                      show_progress=show_progress))
    print(f'--- Query executed in {time.time() - start_time:0,.4f} seconds ---\n')

def get_ordering(infer, variables, evidence=None, elimination_order="MinFill", show_progress=False, desc=""):
    start_time = time.time()
    ordering = infer._get_elimination_order(variables=variables,
                                        evidence=evidence,
                                        elimination_order=elimination_order,
                                        show_progress=show_progress)
    if desc:
        print(desc, ordering, sep='\n')
        print(f'--- Ordering found in {time.time() - start_time:0,.4f} seconds ---\n')
    return ordering

def padding(heuristic):
    return (heuristic + ":").ljust(16)

def compare_all_ordering(infer, variables, evidence=None, show_progress=False):
    ord_dict = {
        "MinFill": get_ordering(infer, variables, evidence, "MinFill", show_progress),
        "MinNeighbors": get_ordering(infer, variables, evidence, "MinNeighbors", show_progress),
        "MinWeight": get_ordering(infer, variables, evidence, "MinWeight", show_progress),
        "WeightedMinFill": get_ordering(infer, variables, evidence, "WeightedMinFill", show_progress)
    }
    if not evidence:
        pre = f'elimination order found for probability query of {variables} with no evidence:'
    else:
        pre = f'elimination order found for probability query of {variables} with evidence {evidence}:'
    if ord_dict["MinFill"] == ord_dict["MinNeighbors"] and ord_dict["MinFill"] == ord_dict["MinWeight"] and ord_dict["MinFill"] == ord_dict["WeightedMinFill"]:
        print(f'All heuristics find the same {pre}.\n{ord_dict["MinFill"]}\n')
    else:
        print(f'Different {pre}')
        for heuristic, order in ord_dict.items():
            print(f'{padding(heuristic)} {order}')
        print()

    
infer_crdt = VariableElimination(model_crdt)

var = ['cpi']
heuristic = "MinNeighbors"
ordering = get_ordering(infer_crdt, variables=var, elimination_order=heuristic,
                        desc=f'Elimination order for {var} with no evidence computed through {heuristic} heuristic:')
query_report(infer_crdt, variables=var, elimination_order=ordering,
             desc=f'Probability query of {var} with no evidence through precomputed elimination order:')
query_report(infer_crdt, variables=var, elimination_order=list(reversed(ordering)),
             desc=f'Probability query of {var} with no evidence through dummy elimination order:')
compare_all_ordering(infer_crdt, variables=var)

var = ['cpi']
ev = {'pr': '<=4', 'wacr': '<4.0' }
heuristic = "MinFill"
query_report(infer_crdt, variables=var, evidence=ev, elimination_order=heuristic,
             desc=f'Probability query of {var} with evidence {ev} computed through {heuristic} heuristic:')
compare_all_ordering(infer_crdt, variables=var, evidence=ev)
heuristic = "MinNeighbors"
query_report(infer_crdt, variables=var, evidence=ev, elimination_order=heuristic,
             desc=f'Probability query of {var} with evidence {ev} computed through {heuristic} heuristic:')
# Out:
# Elimination order for ['cpi'] with no evidence computed through MinNeighbors heuristic:
# ['pr', 'wacr', 'cgr', 'gdpgr']
# --- Ordering found in 0.0047 seconds ---
#
# Probability query of ['cpi'] with no evidence through precomputed elimination order:
# +-------------+------------+
# | cpi         |   phi(cpi) |
# +=============+============+
# | cpi(2 to 3) |     0.1003 |
# +-------------+------------+
# | cpi(3 to 4) |     0.1820 |
# +-------------+------------+
# | cpi(4 to 5) |     0.2126 |
# +-------------+------------+
# | cpi(5 to 6) |     0.2330 |
# +-------------+------------+
# | cpi(<2)     |     0.0289 |
# +-------------+------------+
# | cpi(>6)     |     0.2432 |
# +-------------+------------+
# --- Query executed in 0.0107 seconds ---
#
# Probability query of ['cpi'] with no evidence through dummy elimination order:
# +-------------+------------+
# | cpi         |   phi(cpi) |
# +=============+============+
# | cpi(2 to 3) |     0.1003 |
# ...

# %%
from pgmpy.inference import VariableElimination
import time

def query_report(infer, variables, evidence=None, elimination_order="MinFill", show_progress=False, desc=""):
    if desc:
        print(desc)
    start_time = time.time()
    print(infer.query(variables=variables,
                      evidence=evidence,
                      elimination_order=elimination_order,
                      show_progress=show_progress))
    print(f'--- Query executed in {time.time() - start_time:0,.4f} seconds ---\n')

def get_ordering(infer, variables, evidence=None, elimination_order="MinFill", show_progress=False, desc=""):
    start_time = time.time()
    ordering = infer._get_elimination_order(variables=variables,
                                        evidence=evidence,
                                        elimination_order=elimination_order,
                                        show_progress=show_progress)
    if desc:
        print(desc, ordering, sep='\n')
        print(f'--- Ordering found in {time.time() - start_time:0,.4f} seconds ---\n')
    return ordering

def padding(heuristic):
    return (heuristic + ":").ljust(16)

def compare_all_ordering(infer, variables, evidence=None, show_progress=False):
    ord_dict = {
        "MinFill": get_ordering(infer, variables, evidence, "MinFill", show_progress),
        "MinNeighbors": get_ordering(infer, variables, evidence, "MinNeighbors", show_progress),
        "MinWeight": get_ordering(infer, variables, evidence, "MinWeight", show_progress),
        "WeightedMinFill": get_ordering(infer, variables, evidence, "WeightedMinFill", show_progress)
    }
    if not evidence:
        pre = f'elimination order found for probability query of {variables} with no evidence:'
    else:
        pre = f'elimination order found for probability query of {variables} with evidence {evidence}:'
    if ord_dict["MinFill"] == ord_dict["MinNeighbors"] and ord_dict["MinFill"] == ord_dict["MinWeight"] and ord_dict["MinFill"] == ord_dict["WeightedMinFill"]:
        print(f'All heuristics find the same {pre}.\n{ord_dict["MinFill"]}\n')
    else:
        print(f'Different {pre}')
        for heuristic, order in ord_dict.items():
            print(f'{padding(heuristic)} {order}')
        print()

    
infer_astgr = VariableElimination(model_astgr)

var = ['cpi']
heuristic = "MinNeighbors"
ordering = get_ordering(infer_astgr, variables=var, elimination_order=heuristic,
                        desc=f'Elimination order for {var} with no evidence computed through {heuristic} heuristic:')
query_report(infer_astgr, variables=var, elimination_order=ordering,
             desc=f'Probability query of {var} with no evidence through precomputed elimination order:')
query_report(infer_astgr, variables=var, elimination_order=list(reversed(ordering)),
             desc=f'Probability query of {var} with no evidence through dummy elimination order:')
compare_all_ordering(infer_astgr, variables=var)

var = ['cpi']
ev = {'pr': '<=4', 'wacr': '<4.0' }
heuristic = "MinFill"
query_report(infer_astgr, variables=var, evidence=ev, elimination_order=heuristic,
             desc=f'Probability query of {var} with evidence {ev} computed through {heuristic} heuristic:')
compare_all_ordering(infer_astgr, variables=var, evidence=ev)
heuristic = "MinNeighbors"
query_report(infer_astgr, variables=var, evidence=ev, elimination_order=heuristic,
             desc=f'Probability query of {var} with evidence {ev} computed through {heuristic} heuristic:')
# Out:
# Elimination order for ['cpi'] with no evidence computed through MinNeighbors heuristic:
# ['pr', 'wacr', 'astgr', 'gdpgr']
# --- Ordering found in 0.0040 seconds ---
#
# Probability query of ['cpi'] with no evidence through precomputed elimination order:
# +-------------+------------+
# | cpi         |   phi(cpi) |
# +=============+============+
# | cpi(2 to 3) |     0.1003 |
# +-------------+------------+
# | cpi(3 to 4) |     0.1820 |
# +-------------+------------+
# | cpi(4 to 5) |     0.2126 |
# +-------------+------------+
# | cpi(5 to 6) |     0.2330 |
# +-------------+------------+
# | cpi(<2)     |     0.0289 |
# +-------------+------------+
# | cpi(>6)     |     0.2432 |
# +-------------+------------+
# --- Query executed in 0.0073 seconds ---
#
# Probability query of ['cpi'] with no evidence through dummy elimination order:
# +-------------+------------+
# | cpi         |   phi(cpi) |
# +=============+============+
# | cpi(2 to 3) |     0.1003 |
# ...

# %% [markdown]
# # Directed Acyclic Graph

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a directed graph object
graph = nx.DiGraph()

# Add nodes to the graph
graph.add_nodes_from(['policy rate', 'credit growth', 'call rate', 'real exch.rate', 'asset growth',
                      'Pol.uncertainty', 'inflation', 'GDP', 'investment', 'net export'])

# Add edges to the graph
graph.add_edges_from([('policy rate', 'call rate'),   ('call rate', 'investment'),   ('investment', 'GDP'),
                       ('GDP', 'inflation'), ('policy rate', 'real exch.rate'), ('real exch.rate', 'net export')
                      ,('net export', 'GDP') ,('policy rate', 'credit growth'), ('credit growth', 'GDP'),
                       ('credit growth', 'inflation'),('call rate', 'asset growth'), ('asset growth', 'GDP')
                      , ('credit growth', 'asset growth'), ('real exch.rate', 'inflation'), ('real exch.rate', 'asset growth'),
                       ('real exch.rate', 'credit growth'),  ('call rate', 'real exch.rate'), ('call rate', 'inflation')
                      ,('Pol.uncertainty', 'inflation'), ('asset growth', 'inflation')])

# Set options for graph looks
options = {
    "font_size": 8,
    "node_size": 2000,
    "node_color": "white",
    "edgecolors": "red",
    "linewidths": 3,
    "width": 3}


# Draw the graph
pos = {'policy rate': (0, 10), 'credit growth' : (5, 3), 'call rate': (0, 3), 'real exch.rate': (8, 7), 'asset growth':(10,-3)
       , 'Pol.uncertainty':(-4,4), 'inflation':(2,-12), 'investment':(2.5,-1.8), 'net export':(8,-9), 'GDP':(-3,-5)}
nx.draw(graph, with_labels=True, font_weight='bold', pos = pos,   **options)
plt.title('Directed Acyclic Graph')
plt.figure( dpi = 1000)
plt.show()

# %% [raw]
# import networkx as nx
# import matplotlib.pyplot as plt
#
# # Create a directed graph object
# graph = nx.DiGraph()
#
# # Add nodes to the graph
# graph.add_nodes_from(['policy rate', 'credit growth', 'call rate', 'real exch.rate', 'asset growth',
#                       'Pol.uncertainty', 'inflation', 'GDP', 'investment', 'net export'])
#
# # Add edges to the graph
# graph.add_edges_from([('policy rate', 'call rate'),   ('call rate', 'investment'),   ('investment', 'GDP'),
#                        ('GDP', 'inflation'), ('policy rate', 'real exch.rate'), ('real exch.rate', 'net export')
#                       ,('net export', 'GDP') ,('policy rate', 'credit growth'), ('credit growth', 'GDP'),
#                        ('credit growth', 'inflation'),('call rate', 'asset growth'), ('asset growth', 'GDP')
#                       , ('credit growth', 'asset growth'), ('real exch.rate', 'inflation'), ('real exch.rate', 'asset growth'),
#                        ('real exch.rate', 'credit growth'),  ('call rate', 'real exch.rate'), ('call rate', 'inflation')
#                       ,('Pol.uncertainty', 'inflation'), ('asset growth', 'inflation')])
#
# # Set options for graph looks
# options = {
#     "font_size": 8,
#     "node_size": 2000,
#     "node_color": "white",
#     "edgecolors": "red",
#     "linewidths": 3,
#     "width": 3}
#
#
# # Draw the graph
# pos = {'policy rate': (0, 10), 'credit growth' : (5, 3), 'call rate': (0, 3), 'real exch.rate': (8, 7), 'asset growth':(10,-3)
#        , 'Pol.uncertainty':(-4,4), 'inflation':(2,-12), 'investment':(2.5,-1.8), 'net export':(8,-9), 'GDP':(-3,-5)}
# nx.draw(graph, with_labels=True, font_weight='bold', pos = pos,   **options)
# plt.title('Directed Acyclic Graph')
# plt.figure( dpi = 1000)
# plt.show()

# %% [raw]
# from pgmpy.inference import VariableElimination
# infer = VariableElimination(model)

# %% [raw]
# query_report(infer, variables=['cpi'], evidence={'gdpgr': '8 to 10', 'invgr': '10 to 15'},
#              desc='Probability of cpi when policy rate is uncertianty is most high')

# %% [raw]
# query_report(infer, variables=['cpi'], evidence={'gdpgr': '8 to 10', 'invgr': '10 to 15', 'pr' : '6 to 6.5'},
#              desc='Probability of cpi when policy rate is uncertianty is most high')

# %% [raw]
# query_report(infer, variables=['cpi'], evidence={'gdpgr': '8 to 10', 'invgr': '10 to 15', 'pr' : '5.0 to 5.5'},
#              desc='Probability of cpi when policy rate is uncertianty is most high')

# %%
df.columns
# Out:
# Index(['pr', 'wacr', 'rer', 'gpr', 'cpi', 'cgr', 'astgr', 'gdpgr', 'invgr',
#        'nxpgr'],
#       dtype='object')

# %% [raw]
# # Printing a CPD with it's state names defined.
# print(model.get_cpds('cpi'))

# %%
df1.columns
# Out:
# Index(['Weighted average call rate', 'Bank credit', 'policy rate', 'real ER',
#        'asset price', 'GPR', 'CPI', 'gdp', 'investment', 'net export',
#        'creditgrowth', 'assetgrowth', 'gdpRate', 'investmentRate',
#        'netexportRate', 'real ER growth', 'GPrRate'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['pr', 'wacr', 'rer', 'gpr', 'cpi', 'cgr', 'astgr', 'gdpgr', 'invgr',
#        'nxpgr'],
#       dtype='object')

# %% [raw]
# # Fitting the model using Maximum Likelihood Estimator
#
# from pgmpy.estimators import MaximumLikelihoodEstimator
#
# mle = MaximumLikelihoodEstimator(model=model_int, data=df_int)
#
# # Estimating the CPD for a single node.
# print(mle.estimate_cpd(node="pr"))
# print(mle.estimate_cpd(node="invgr"))

# %% [raw]
# # Calibrate all CPDs of `model` using MLE:
# model_int.fit(df_int, estimator=MaximumLikelihoodEstimator)

# %% [raw]
# infer = VariableElimination(model_int)

# %% [raw]
# query_report(infer, variables=['cpi' , 'gdpgr'], evidence = {'pr': '5.5 to 6.0'},
#              desc='Probability of cpi when policy rate is uncertianty is most high')

# %% [raw]
# from pgmpy.estimators import BayesianEstimator
# est = BayesianEstimator(model_int, df_int)
# model_int.fit(df_int, estimator=BayesianEstimator, prior_type="BDeu")

# %% [raw]
# model_int.fit(df_int, estimator=BayesianEstimator, prior_type="BDeu")

# %%
print(model_int.get_cpds('pr'))
# Out:
# +----------------+-----------+
# | pr(4.0 to 4.5) | 0.0362812 |
# +----------------+-----------+
# | pr(4.5 to 5.0) | 0.0260771 |
# +----------------+-----------+
# | pr(5.0 to 5.5) | 0.0873016 |
# +----------------+-----------+
# | pr(5.5 to 6.0) | 0.148526  |
# +----------------+-----------+
# | pr(6 to 6.5)   | 0.270975  |
# +----------------+-----------+
# | pr(6.5 to 7.0) | 0.0668934 |
# +----------------+-----------+
# | pr(7.0 to 7.5) | 0.0770975 |
# +----------------+-----------+
# | pr(7.5 to 8.0) | 0.0260771 |
# +----------------+-----------+
# | pr(<=4)        | 0.260771  |
# +----------------+-----------+

# %% [raw]
# print(est.estimate_cpd(node="pr", prior_type="BDeu"))

# %% [raw]
# # Learning CPDs for all the nodes in the model.
# est.get_parameters(prior_type="BDeu")

# %% [raw]
# query_report(infer_int, variables=['cpi' , 'gdpgr'], evidence = {'pr': '>6.0'},
#              desc='Probability of cpi when policy rate is uncertianty is most high')

# %% [raw]
# infer_int.map_query(['cpi', 'gdpgr'],evidence = {'pr': '>6.0'})

# %% [raw]
# query_report(infer_int, variables=['cpi' , 'gdpgr'], evidence = {'pr': '<4.0x<6.0'},
#              desc='Probability of cpi when policy rate is uncertianty is most high')

# %% [raw]
# infer_int.map_query(['cpi', 'gdpgr'],evidence = {'pr': '<4.0'})

# %% [raw]
# # infer_int.map_query(['cpi', 'gdpgr'],evidence = {'pr': '<4.0x<6.0'})

# %%
df.pr.value_counts()
# Out:
# 6 to 6.5      26
# <=4           25
# 5.5 to 6.0    14
# 5.0 to 5.5     8
# 7.0 to 7.5     7
# 6.5 to 7.0     6
# 4.0 to 4.5     3
# 4.5 to 5.0     2
# 7.5 to 8.0     2
# Name: pr, dtype: int64

# %%
df1.columns
# Out:
# Index(['Weighted average call rate', 'Bank credit', 'policy rate', 'real ER',
#        'asset price', 'GPR', 'CPI', 'gdp', 'investment', 'net export',
#        'creditgrowth', 'assetgrowth', 'gdpRate', 'investmentRate',
#        'netexportRate', 'real ER growth', 'GPrRate'],
#       dtype='object')

# %%
df1.describe()
# Out:
#        Weighted average call rate   Bank credit  policy rate     real ER  \
# count                   93.000000  9.300000e+01    93.000000   93.000000
# mean                     5.380538  9.091705e+06     5.606989   99.132473
# std                      1.404859  1.765514e+06     1.174586    2.377497
# min                      3.120000  6.386975e+06     4.000000   93.500000
# 25%                      3.720000  7.410062e+06     4.000000   97.390000
# 50%                      5.910000  9.221898e+06     6.000000   99.420000
# 75%                      6.390000  1.038795e+07     6.500000  101.010000
# max                      7.890000  1.304179e+07     7.750000  103.370000
#
#         asset price         GPR        CPI           gdp    investment  \
# count     93.000000   93.000000  93.000000  9.300000e+01  9.300000e+01
# mean   37748.222117  102.129143   4.876882  3.118849e+06  3.620493e+06
# std    10689.875474   35.317894   1.497780  3.277301e+05  7.479108e+05
# ...

# %%
df1.columns
# Out:
# Index(['Weighted average call rate', 'Bank credit', 'policy rate', 'real ER',
#        'asset price', 'GPR', 'CPI', 'gdp', 'investment', 'net export',
#        'creditgrowth', 'assetgrowth', 'gdpRate', 'investmentRate',
#        'netexportRate', 'real ER growth', 'GPrRate'],
#       dtype='object')

# %%
df1.CPI.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.scatter(df1['GPR'], df1['CPI'])
plt.show()

# %%
np.cov(df1['GPR'], df1['CPI'])
# Out:
# array([[1247.3536672 ,    9.12730298],
#        [   9.12730298,    2.24334343]])

# %%
from scipy.stats import pearsonr
pearsonr(df1['GPR'], df1['CPI'])
# Out:
# (0.17254396778074763, 0.09815218375153166)

# %%
df1.corr()
# Out:
#                             Weighted average call rate  Bank credit  \
# Weighted average call rate                    1.000000    -0.826997
# Bank credit                                  -0.826997     1.000000
# policy rate                                   0.986443    -0.875367
# real ER                                      -0.491170     0.443662
# asset price                                  -0.774114     0.911522
# GPR                                           0.003768     0.144360
# CPI                                          -0.454262     0.427654
# gdp                                          -0.725630     0.879111
# investment                                   -0.895643     0.955769
# net export                                    0.245195    -0.602819
# creditgrowth                                  0.441499     0.046647
# assetgrowth                                  -0.316928     0.217777
# gdpRate                                       0.116411    -0.182221
# ...

# %% [raw]
# print(model.get_cpds('wacr'))

# %%
df1.columns
# Out:
# Index(['Weighted average call rate', 'Bank credit', 'policy rate', 'real ER',
#        'asset price', 'GPR', 'CPI', 'gdp', 'investment', 'net export',
#        'creditgrowth', 'assetgrowth', 'gdpRate', 'investmentRate',
#        'netexportRate', 'real ER growth', 'GPrRate'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['pr', 'wacr', 'rer', 'gpr', 'cpi', 'cgr', 'astgr', 'gdpgr', 'invgr',
#        'nxpgr'],
#       dtype='object')

# %%
df1[['Weighted average call rate', 'policy rate']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Our first task is to analyses the change in inflation rate and gross domestic product in response to the change in policy rate through investment. Impact

# %%
print(df.pr.value_counts())
print(df.cpi.value_counts())
print(df.gdpgr.value_counts())
print(df.invgr.value_counts())
# Out:
# 6 to 6.5      26
# <=4           25
# 5.5 to 6.0    14
# 5.0 to 5.5     8
# 7.0 to 7.5     7
# 6.5 to 7.0     6
# 4.0 to 4.5     3
# 4.5 to 5.0     2
# 7.5 to 8.0     2
# Name: pr, dtype: int64
# >6        23
# 5 to 6    22
# 4 to 5    20
# 3 to 4    17
# 2 to 3     9
# <2         2
# Name: cpi, dtype: int64
# >9          11
# 7 to 7.5    10
# 4.5 to 5    10
# 2 to 4       9
# 6 to 6.5     8
# 7.5 to 8     8
# <=0          7
# 5 to 5.5     7
# 8 to 8.5     6
# 4 to 4.5     4
# 6.5 to 7     4
# 5.5 to 6     4
# 8.5 to 9     4
# 0 to 2       1
# Name: gdpgr, dtype: int64
# >10        44
# 5 to 10    25
# <=5        24
# Name: invgr, dtype: int64

# %% [markdown]
# ###### Impact of policy rate on CPI through interest rate channel

# %%
infer_int.map_query(['cpi'],evidence = {'pr': '6.5 to 7.0'})
# Out:
# C:\Users\NIYAZ AHMED\anaconda3\lib\site-packages\pgmpy\models\BayesianModel.py:8: FutureWarning: BayesianModel has been renamed to BayesianNetwork. Please use BayesianNetwork class, BayesianModel will be removed in future.
#   warnings.warn(
# ...
#   0%|          | 0/3 [00:00<?, ?it/s]
# {'cpi': '>6'}

# %%
query_report(infer_int, variables=['cpi' ], evidence = {'pr': '6.5 to 7.0'},
             desc='Probability of cpi when policy rate is.....')
# Out:
# Probability of cpi when policy rate is.....
# +-------------+------------+
# | cpi         |   phi(cpi) |
# +=============+============+
# | cpi(2 to 3) |     0.1017 |
# +-------------+------------+
# | cpi(3 to 4) |     0.1816 |
# +-------------+------------+
# | cpi(4 to 5) |     0.2123 |
# +-------------+------------+
# | cpi(5 to 6) |     0.2325 |
# +-------------+------------+
# | cpi(<2)     |     0.0289 |
# +-------------+------------+
# | cpi(>6)     |     0.2430 |
# +-------------+------------+
# --- Query executed in 0.0089 seconds ---

# %%
query_report(infer_int, variables=['cpi' ], evidence = {'pr': '7.0 to 7.5'},
             desc='Probability of cpi when policy rate is.....')
# Out:
# Probability of cpi when policy rate is.....
# +-------------+------------+
# | cpi         |   phi(cpi) |
# +=============+============+
# | cpi(2 to 3) |     0.1017 |
# +-------------+------------+
# | cpi(3 to 4) |     0.1816 |
# +-------------+------------+
# | cpi(4 to 5) |     0.2123 |
# +-------------+------------+
# | cpi(5 to 6) |     0.2325 |
# +-------------+------------+
# | cpi(<2)     |     0.0289 |
# +-------------+------------+
# | cpi(>6)     |     0.2430 |
# +-------------+------------+
# --- Query executed in 0.0060 seconds ---

# %%
query_report(infer_int, variables=['cpi' ], evidence = {'pr': '7.5 to 8.0'},
             desc='Probability of cpi when policy rate is.....')
# Out:
# Probability of cpi when policy rate is.....
# +-------------+------------+
# | cpi         |   phi(cpi) |
# +=============+============+
# | cpi(2 to 3) |     0.1014 |
# +-------------+------------+
# | cpi(3 to 4) |     0.1817 |
# +-------------+------------+
# | cpi(4 to 5) |     0.2123 |
# +-------------+------------+
# | cpi(5 to 6) |     0.2326 |
# +-------------+------------+
# | cpi(<2)     |     0.0289 |
# +-------------+------------+
# | cpi(>6)     |     0.2431 |
# +-------------+------------+
# --- Query executed in 0.0109 seconds ---

# %% [markdown]
# ###### Impact of policy rate on gdp through interest rate channel

# %%
infer_int.map_query(['gdpgr'],evidence = {'pr': '6.5 to 7.0'})
# Out:
# ...
#   0%|          | 0/2 [00:00<?, ?it/s]
# {'gdpgr': '>9'}

# %%
query_report(infer_int, variables=['gdpgr' ], evidence = {'pr': '6.5 to 7.0'},
             desc='Probability of cpi when policy rate is.....')
# Out:
# Probability of cpi when policy rate is.....
# +-----------------+--------------+
# | gdpgr           |   phi(gdpgr) |
# +=================+==============+
# | gdpgr(0 to 2)   |       0.0139 |
# +-----------------+--------------+
# | gdpgr(2 to 4)   |       0.0954 |
# +-----------------+--------------+
# | gdpgr(4 to 4.5) |       0.0466 |
# +-----------------+--------------+
# | gdpgr(4.5 to 5) |       0.1078 |
# +-----------------+--------------+
# | gdpgr(5 to 5.5) |       0.0751 |
# +-----------------+--------------+
# | gdpgr(5.5 to 6) |       0.0433 |
# +-----------------+--------------+
# | gdpgr(6 to 6.5) |       0.0842 |
# +-----------------+--------------+
# | gdpgr(6.5 to 7) |       0.0440 |
# +-----------------+--------------+
# | gdpgr(7 to 7.5) |       0.1068 |
# +-----------------+--------------+
# | gdpgr(7.5 to 8) |       0.0830 |
# +-----------------+--------------+
# | gdpgr(8 to 8.5) |       0.0651 |
# +-----------------+--------------+
# ...

# %%
model_int.edges
# Out:
# OutEdgeView([('pr', 'wacr'), ('wacr', 'invgr'), ('invgr', 'gdpgr'), ('gdpgr', 'cpi')])

# %%
query_report(infer_int, variables=['gdpgr' ], evidence = {'pr': '7.0 to 7.5'},
             desc='Probability of cpi when policy rate is.....')
# Out:
# Probability of cpi when policy rate is.....
# +-----------------+--------------+
# | gdpgr           |   phi(gdpgr) |
# +=================+==============+
# | gdpgr(0 to 2)   |       0.0139 |
# +-----------------+--------------+
# | gdpgr(2 to 4)   |       0.0954 |
# +-----------------+--------------+
# | gdpgr(4 to 4.5) |       0.0466 |
# +-----------------+--------------+
# | gdpgr(4.5 to 5) |       0.1078 |
# +-----------------+--------------+
# | gdpgr(5 to 5.5) |       0.0751 |
# +-----------------+--------------+
# | gdpgr(5.5 to 6) |       0.0433 |
# +-----------------+--------------+
# | gdpgr(6 to 6.5) |       0.0842 |
# +-----------------+--------------+
# | gdpgr(6.5 to 7) |       0.0440 |
# +-----------------+--------------+
# | gdpgr(7 to 7.5) |       0.1069 |
# +-----------------+--------------+
# | gdpgr(7.5 to 8) |       0.0830 |
# +-----------------+--------------+
# | gdpgr(8 to 8.5) |       0.0651 |
# +-----------------+--------------+
# ...

# %% [raw]
# print(f'There can be made {len(model.get_independencies().get_assertions())}',
#       'valid independence assertions with respect to the all possible given evidence.')
# print('For instance, any node in the network is independent of its non-descendents given its parents (local semantics):\n',
#       f'\n{model.local_independencies(nodes)}\n')

# %% [raw]
# From our first scenario where we chose to see how inflaiton rate adjusts with respect to policy rate, we find that an increase
# in the policy rate has decreases the inflation. From a policy maker perspecitive, we say that the probability of inflation
# settling between 2 and 5 when the interest rate is above 6 is 43%. In other words, the central bank strategy of influencing the inflation rate by through interest rate is close to 50%. Simply put, the CB is strategy of interest rate change is approximately 50% effective.

# %% [raw]
# ::Impact of policy rate on GDP::

# %%
infer_int.map_query(['gdpgr'],evidence = {'pr': '<=4'})
# Out:
# ...
#   0%|          | 0/2 [00:00<?, ?it/s]
# {'gdpgr': '>9'}

# %%
nodes = ['pr',  'wacr',  'cpi', 'gdpgr',  'invgr']
print(f'There can be made {len(model_int.get_independencies().get_assertions())}',
      'valid independence assertions with respect to the all possible given evidence.')
print('For instance, any node in the network is independent of its non-descendents given its parents (local semantics):\n',
      f'\n{model_int.local_independencies(nodes)}\n')
# Out:
# There can be made 45 valid independence assertions with respect to the all possible given evidence.
# For instance, any node in the network is independent of its non-descendents given its parents (local semantics):
#
# (cpi ⟂ wacr, invgr, pr | gdpgr)
# (gdpgr ⟂ wacr, pr | invgr)
# (invgr ⟂ pr | wacr)

# %% [raw]
# Having looked at the impact of policy rate on the growth of the indian economy, we can safely say that based on out dataset
# for the past eight years, despite rise the policy rate , the probability that the  economy shall grow at 7% is 45%.

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a directed graph object
graph = nx.DiGraph()

# Add nodes to the graph
graph.add_nodes_from(['policy rate',  'call rate', 'inflation', 'GDP', 'investment'])

# Add edges to the graph
graph.add_edges_from([('policy rate', 'call rate'),   ('call rate', 'investment'),   ('investment', 'GDP'),
                       ('GDP', 'inflation')])

# Set options for graph looks
options = {
    "font_size": 8,
    "node_size": 2000,
    "node_color": "white",
    "edgecolors": "red",
    "linewidths": 3,
    "width": 3}


# Draw the graph

nx.draw(graph, with_labels=True, font_weight='bold', pos = pos,   **options)
plt.title('Directed Acyclic Graph')
plt.figure( dpi = 1000)
plt.show()

# %% [raw]
# import networkx as nx
# import matplotlib.pyplot as plt
#
# # Create a directed graph object
# graph = nx.DiGraph()
#
# # Add nodes to the graph
# graph.add_nodes_from(['policy rate',  'call rate', 'real exch.rate', 'inflation', 'GDP',  'net export'])
#
# # Add edges to the graph
# graph.add_edges_from([('policy rate', 'call rate'),   ('call rate', 'investment'),   ('investment', 'GDP'),
#                        ('GDP', 'inflation'), ('policy rate', 'real exch.rate'), ('real exch.rate', 'net export')
#                       ,('net export', 'GDP') ,('policy rate', 'credit growth'), ('credit growth', 'GDP'),
#                        ('credit growth', 'inflation'),('call rate', 'asset growth'), ('asset growth', 'GDP')
#                       , ('credit growth', 'asset growth'), ('real exch.rate', 'inflation'), ('real exch.rate', 'asset growth'),
#                        ('real exch.rate', 'credit growth'),  ('call rate', 'real exch.rate'), ('call rate', 'inflation')
#                       ,('Pol.uncertainty', 'inflation'), ('asset growth', 'inflation')])
#
# # Set options for graph looks
# options = {
#     "font_size": 8,
#     "node_size": 2000,
#     "node_color": "white",
#     "edgecolors": "red",
#     "linewidths": 3,
#     "width": 3}
#
#
# # Draw the graph
# pos = {'policy rate': (0, 10), 'call rate': (0, 3), 'real exch.rate': (8, 7), 'inflation':(2,-12),  'net export':(8,-9), 'GDP':(-3,-5)}
# nx.draw(graph, with_labels=True, font_weight='bold', pos = pos,   **options)
# plt.title('Directed Acyclic Graph')
# plt.figure( dpi = 1000)
# plt.show()

# %%
query_report(infer, variables=['cpi' ], evidence = {'invgr': '5 to 10'},
             desc='Probability of cpi when policy rate is.....')
# Out:
# Probability of cpi when policy rate is.....
# +-------------+------------+
# | cpi         |   phi(cpi) |
# +=============+============+
# | cpi(2 to 3) |     0.1513 |
# +-------------+------------+
# | cpi(3 to 4) |     0.1674 |
# +-------------+------------+
# | cpi(4 to 5) |     0.1794 |
# +-------------+------------+
# | cpi(5 to 6) |     0.1861 |
# +-------------+------------+
# | cpi(<2)     |     0.1473 |
# +-------------+------------+
# | cpi(>6)     |     0.1685 |
# +-------------+------------+
# --- Query executed in 0.0293 seconds ---

# %%
query_report(infer, variables=['pr' ], evidence = {'invgr': '5 to 10'},
             desc='Probability of cpi when policy rate is.....')
# Out:
# Probability of cpi when policy rate is.....
# +----------------+-----------+
# | pr             |   phi(pr) |
# +================+===========+
# | pr(4.0 to 4.5) |    0.0444 |
# +----------------+-----------+
# | pr(4.5 to 5.0) |    0.0315 |
# +----------------+-----------+
# | pr(5.0 to 5.5) |    0.1089 |
# +----------------+-----------+
# | pr(5.5 to 6.0) |    0.1830 |
# +----------------+-----------+
# | pr(6 to 6.5)   |    0.2595 |
# +----------------+-----------+
# | pr(6.5 to 7.0) |    0.0627 |
# +----------------+-----------+
# | pr(7.0 to 7.5) |    0.0722 |
# +----------------+-----------+
# | pr(7.5 to 8.0) |    0.0247 |
# +----------------+-----------+
# | pr(<=4)        |    0.2134 |
# +----------------+-----------+
# --- Query executed in 0.0096 seconds ---

# %% [raw]
# looking at the last three results, we infer the following:
# When the investment india grew at a rate of (5,10) %, the probability that the inflation rate would remain above the comfort zone >6

# %%
df.columns
# Out:
# Index(['pr', 'wacr', 'rer', 'gpr', 'cpi', 'cgr', 'astgr', 'gdpgr', 'invgr',
#        'nxpgr'],
#       dtype='object')

# %%
df.invgr.value_counts()
# Out:
# >10        44
# 5 to 10    25
# <=5        24
# Name: invgr, dtype: int64

# %%
print(infer.query(['cpi'], evidence = {'invgr': '>10'}))
# Out:
# +-------------+------------+
# | cpi         |   phi(cpi) |
# +=============+============+
# | cpi(2 to 3) |     0.1541 |
# +-------------+------------+
# | cpi(3 to 4) |     0.1546 |
# +-------------+------------+
# | cpi(4 to 5) |     0.1722 |
# +-------------+------------+
# | cpi(5 to 6) |     0.1954 |
# +-------------+------------+
# | cpi(<2)     |     0.1439 |
# +-------------+------------+
# | cpi(>6)     |     0.1798 |
# +-------------+------------+

# %%
import numpy as np
import pandas as pd
from pgmpy.models import BayesianNetwork
values = pd.DataFrame(np.random.randint(low=0, high=2, size=(1000, 5)), columns=['A', 'B', 'C', 'D', 'E'])
train_data = values[:800]
predict_data = values[800:]
model = BayesianNetwork([('A', 'B'), ('C', 'B'), ('C', 'D'), ('B', 'E')])
model.fit(train_data)  #this fits the complete data
predict_data = predict_data.copy()
predict_data.drop('E', axis=1, inplace=True)
y_pred = model.predict(predict_data)
y_pred
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
#      E
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 195  0
# 196  0
# 197  0
# 198  0
# 199  0
#
# [200 rows x 1 columns]
